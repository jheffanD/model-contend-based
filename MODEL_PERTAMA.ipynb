# %%
# !gdown "1Uyn-YTcE_n-k4QQX6Uds5PA6SK327Orx" --output myntra.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Uyn-YTcE_n-k4QQX6Uds5PA6SK327Orx
# To: /content/myntra.csv
# 100% 3.16M/3.16M [00:00<00:00, 161MB/s]

# %%
# Library
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/myntra.csv")
df = pd.read_csv('myntra.csv')

# %% [markdown]
# #Info Data Awal

# %%
# Tampilkan dimensi DataFrame (baris, kolom)
print(f"Dimensi DataFrame df: {df.shape[0]} baris, {df.shape[1]} kolom")
# Out:
# Dimensi DataFrame df: 12491 baris, 8 kolom

# %%
# Tampilkan informasi ringkas semua kolom, tipe data, dan jumlah non-null
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12491 entries, 0 to 12490
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     12491 non-null  int64
#  1   ProductName   12491 non-null  object
#  2   ProductBrand  12491 non-null  object
#  3   Gender        12491 non-null  object
#  4   Price (INR)   12491 non-null  int64
#  5   NumImages     12491 non-null  int64
#  6   Description   12491 non-null  object
#  7   PrimaryColor  11597 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 780.8+ KB
# None

# %%
# Tampilkan seluruh DataFrame
df.head(5)
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)  NumImages  \
# 0  Unisex        11745          7
# 1   Women         5810          7
# 2   Women          899          7
# 3     Men         5599          5
# 4     Men          759          5
#
#                                          Description PrimaryColor
# 0  Black and grey printed medium trolley bag, sec...        Black
# 1  Beige & Grey made to measure kurta with churid...        Beige
# 2  Pink coloured wash 5-pocket high-rise cropped ...         Pink
# ...

# %%
# prompt: buatkan codee untuk prrint isi dari tabel ProductName dengan ProductID[10017413]

# Print ProductName for ProductID 10017413
product_name = df[df['ProductID'] == 10017833]['Description'].iloc[0]
# print(f"ProductName for ProductID 10017413: {product_name}")
product_name
# Out:
# 'Brown and off-white printed casual shirt, has a spread collar, long sleeves, button placket,  curved hem, one patch pocket'

# %% [markdown]
# #Mengecek Jumlah Missing Values & Duplicate

# %%
# Mengecek jumlah missing values di setiap kolom
missing_values = df.isnull().sum()
print("Jumlah Missing Values Sebelum Dibersihkan:")

# Menampilkan jumlah missing values
print(missing_values)
print()

# Mengecek jumlah data duplikat
duplicate_count = df.duplicated().sum()

# Menampilkan jumlah data duplikat
print(f"Jumlah Duplikat Sebelum Dibersihkan: {duplicate_count}")
# Out:
# Jumlah Missing Values Sebelum Dibersihkan:
# ProductID         0
# ProductName       0
# ProductBrand      0
# Gender            0
# Price (INR)       0
# NumImages         0
# Description       0
# PrimaryColor    894
# dtype: int64
#
# Jumlah Duplikat Sebelum Dibersihkan: 0

# %% [markdown]
# #Menghapus Missing Values & Duplicate

# %%
# Menghapus baris yang memiliki nilai kosong (missing values)
df = df.dropna()

# Menghapus baris yang duplikat (semua kolom identik)
df = df.drop_duplicates()

# %% [markdown]
# #Mengecek Info Baru Missing Values & Duplicate

# %%
print("Jumlah Missing Values Setelah Dibersihkan:")
# Memeriksa apakah masih ada NaN setelah pembersihan
print(df.isna().sum())
print()

print("Jumlah Duplikat Setelah Dibersihkan:")
# Memeriksa apakah masih ada data duplikat setelah pembersihan
print(df.duplicated().sum())
# Out:
# Jumlah Missing Values Setelah Dibersihkan:
# ProductID       0
# ProductName     0
# ProductBrand    0
# Gender          0
# Price (INR)     0
# NumImages       0
# Description     0
# PrimaryColor    0
# dtype: int64
#
# Jumlah Duplikat Setelah Dibersihkan:
# 0

# %% [markdown]
# #Info data baru setelah di cleaning

# %%
# Menampilkan informasi ringkas tentang DataFrame df_cleaned
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11597 entries, 0 to 12490
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     11597 non-null  int64
#  1   ProductName   11597 non-null  object
#  2   ProductBrand  11597 non-null  object
#  3   Gender        11597 non-null  object
#  4   Price (INR)   11597 non-null  int64
#  5   NumImages     11597 non-null  int64
#  6   Description   11597 non-null  object
#  7   PrimaryColor  11597 non-null  object
# dtypes: int64(3), object(5)
# memory usage: 815.4+ KB

# %% [markdown]
# #Menghapus Kolom yang tidak penting

# %%
# Menghapus kolom yang tidak penting
df= df.drop(columns=['NumImages'])

# Menampilkan data setelah penghapusan kolom
df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2       10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...          ...                                                ...
# 12485   10261595  Laceandme Black Lace Non-Wired Lightly Padded ...
# 12486   10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12488   10261607  612 league Girls Navy Blue & White Printed Reg...
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  \
# 0             DKNY  Unisex        11745
# 1       EthnoVogue   Women         5810
# ...

# %%
import re

# Daftar kata kunci atau kategori produk yang ingin diambil
product_categories = ['Medium Trolley Bag', 'Kurta Set with Jacket', 'Stretchable Cropped Jeans', 'Single-Breasted Bandhgala Suit', 'Chinos', 'Wedges', 'Solid Heels', 'Casual Shirt',
                      'Biker Jacket', 'Capris', 'MDF Coasters', 'Sports Sweatshirt', 'Printed Dupatta', 'Regular Shorts', 'Stretchable Ankle Jeans', 'Regular Trousers', 'Large Trolley Bag',
                      'Casual Slim Shirt', 'Edt 75ml', 'Flat Boots', 'Solid Backpack', 'Tights', 'Core Sneakers', 'Duffle Bag', 'Kurta with Palazzos', 'Satin Skirt', 'Boxy Top', 'Bangle',
                      'Cabin Trolley Suitcase', 'Polo Collar T-shirt', 'Table Placemats', 'Hair Dryer', 'Tracksuit', 'Formal Trousers', 'Painted Flower Vase', 'Table Lamp with Shade', 'Straight Kurta',
                      'Leather Sandals', 'Cushioned Slip-Ons', 'Round Neck T-shirt', 'Checked Formal Trousers', 'Edt 70 ml', 'Leather Sneakers', 'Flare Dress', ' Embroidered Tunic',
                      'Maternity Bra', 'Embellished Dress', 'Plunge Bra', 'Ankle-Length Stretchable Jeans', 'Leather Mid-Top Flat Boots', 'Owl Motif Coaster Set', 'Laser Cuts Sneakers',
                      'Agile T1 Nm Wn S Idp Sneakers', 'Printed Curtain', 'Black-Quarry', 'Sports Shorts', 'T-shirt Bra', 'T-Shirt Bra', 'Linen Shirt', '1 King Bedsheet with 2 Pillow Covers',
                      'Matte Melt Liquid Lip Color - 15 Rose Love 6 ml', 'Front Open Sweater', 'Anklets', 'Mid-Top Sneakers', 'Canvas Mid-Top Sneakers', 'Slip-On Shoes', 'Slip-on Shoes',
                      'Kurta with Dhoti Pants & Jacket', 'Indian Art Printed Set of 4 Ceramic Bowls', 'Geometric Cufflinks', 'Bikini Briefs', '1 Kingbedsheet with 2 Pillow Covers',
                      'Edp 90Ml', 'Tan Brogues', 'Bikini Brief', 'Leather Loafers', 'Eau De Toilette Perfume 100 ml', 'Matte Melt Liquid Lip Color - 23 Pink Poison 6 ml', 'Self Design Top',
                      'Distressed Jeans', 'Medium Laptop Backpack', 'Round Neck Faux Leather T-shirt', 'Storage Jars Lids', 'Sports Bra', 'Wooden Open Dry Bin', '19.1 Spikes', 'Ceramic Bath Accessories',
                      'Pack of 2 Beginners Bras', 'Cushioned Loafers', 'A-line Top', 'A-Line Top', 'Round Cufflinks', 'Basic Playsuit', 'Clean Look Jeans', 'Cushioned Flats', 'Bomber Jacket',
                      'Denim Jacket', 'Trackpants', 'Shirt Dress', 'Varsity Jacket', 'Set of 4 Bowls', 'Formal Slip-ons', 'Embellished Clutch', 'Leather Oxfords', 'Ceramic Mug', 'Pleats Top',
                      'Hipster Brief', 'Everyday Bra', 'Gel Lipstick, 1.6gm', 'Handcrafted Ceramic', 'A-Line Dress', 'Regular Fit Shorts', 'Head Chain', 'Eau Parfum 100 ml', 'Solid Top',
                      'Sliders', 'Statement Ring', 'Matte Paste 100 ml', 'Eau De Toilette 40 ml', 'Gel Lipstick 1.6 g', 'Thong Flip-Flops', 'Textured Belt', 'Eau Toilette Perfume 65 ml',
                      'Coffee Mugs Cum Serving Tea Cups Set', 'Minimizer Bra', 'Mangalsutra', 'Cabin Trolley Bag', 'Cover-Up Dress', 'Face Beard Wash 100gm', 'Pack Of 2 Everyday Bras',
                      'Eau Toilette 50 ml', 'Edt 50 ml', 'Formal Derbys with Perforated Detail', 'Sherwani Set', 'Printed Trousers', 'Comfort Heels', 'Lace Boy Shorts', 'Eau De Parfum 75 ml',
                      'Ankle-length Stretchable Jeans', 'Hooded Sweatshirt', 'Leather Formal Slip-Ons', 'Self Design Formal Trousers', 'LacquerInk Lip Shine 6ml', 'Belted Dress', 'Tiered Dress',
                      'Matte Melt Liquid Lip - 21 Mauve Mix 6 ml', 'Henley Neck T-Shirt', 'Henley Neck T-shirt', 'Flower-Shaped Nosepin', 'Sleeveless', 'Hoop Earrings', 'Slim Fit Jeans', 'Rectangular Photo Frame',
                      'Mattreal Mousse Concealer', 'Ceramic Cups', 'Eau Toilette 90 ml', 'Drop Earrings', 'Leather Backpack with Pouch', 'Pinafore Dress', 'Maxi Dress', 'Mojaris',
                      'Floral AC Room 300 GSM Single Bed Dohar', 'Cotton Boxers', 'Wide Leg Palazzos', 'Printed Ceramic Tea Cups Set', ' Ceramic Cup', 'Kurta with Pyjamas', 'Peplum Top', 'Eau De Parfum 50 ml',
                      'Digital Watch', 'Digital watch', 'Geometric Drop Earrings', 'Comfort Sandals', 'Balconette Bra', 'Nehru Jacket', 'Sterling Silver Drop Earrings', 'Circular Studs',
                      'Chambray Top with Shorts', 'Eau De Perfume 90 ml', 'Kurta with Churidar & Jacket', 'Peep Toes', 'Flecked T-shirt', 'Table Top Planter', 'Open Toe Heels', 'Scarf',
                      'Skinny Jeans', 'Quartet Eyeshadow', 'Kanjeevaram Saree', 'Formal Blazer', 'Ceramic Art Storage Jar', 'Striped Briefs', 'Printed Kurta', 'Melange T-shirt', 'Edp 100ml',
                      'Eau de Toilette 125 ml', 'Party Suit', 'Solid Palazzos', 'Layered Dress', 'Ceramic Coffee Mugs', 'Ceramic Coffee Mug','Rectangle Cufflinks', 'Quirky Cufflinks',
                      'Kitchen Storage Jars with Lids', 'Bowl Set', 'Nose Ring Chain', 'Chambray Shirt', 'Set Of 6 Coffee Mugs', 'CASTLEROCK-Rhubarb Sneakers', 'T-shirt Bras', 'Cargos',
                      'Single-Breasted Blazer', 'Jewelry Set',  'Maang Tika', 'Gotta Patti Dupatta', 'Khullad Cups', 'Square Photo Frame', 'Semiformal Shirt', 'Turin II Sneakers', 'Printed Trunk',
                      'Embroidered Clutch', 'Striped T-shirt', 'Sustainable Dress', 'Cigarette Trousers', 'Distress Stretchable Jeans', 'Low-Rise Hipsters', 'Stretchable Ankle-length Jeans',
                      'Eau Parfum Spray 100 ml', 'Striped Woollen Bodysuit', 'Shirt-Style Tunic', 'Maternity Trousers', 'Printed Shorts', 'Eau Toilette 100 ml', 'Pure Cotton Printed', 'Linen Sheath Dress',
                      'Single-Breasted Formal Suit', 'Semi-Sheer Top', 'Edp 50ml', 'Dhoti Jumpsuit', 'Whiskey Glasses', 'Acrylic Soap Dispenser', 'Leather Oxfords', 'Solid Backpack',
                      'Intense Acne Clearing Face Wash 100gm', 'Oxidised Sterling Silver Ring', 'Chambray Slim-Fit Jacket', 'Square Cushion Covers', 'Floral Printed Maxi', 'Cocktail Glasses',
                      'Biker PU Jacket', 'Striped Tank', 'Handcrafted Jewellery Set', 'Hipster Briefs', 'Sheath Dress', 'Shirt Style Top', 'Jhumka Earrings', 'Collar T-shirt', 'Table Runner',
                      'Striped Boxers', 'Corner Wall Shelves', 'Coffee Mug', 'Distressed Ankle-length Jeans', 'Cotton Waistcoat', 'Single Window Curtains', 'Sheer Top', 'Plating Jewellery Set',
                      'Circular Drop Earrings', 'Storage Jar', 'Single Bed Comforter', 'Washed Skorts', 'Lounge Pants', 'Single-Breasted Bandhgala', 'Lace Wrap Dress', 'Sequinned Top',
                      'Nose Ring', 'Intense Acne Therapy Kit', 'Tie & Dye Kaftan Top', 'Joggers', 'Travel Pouch', 'Hooded T-shirt', 'Face Wash 200gm', 'Ethnic Blazer', 'Checked Culottes',
                      'Straight Kurta', 'Swanshaped Brooch', 'Edp 50 ml', 'Double Bed Dohar', 'Semi-Sheer Solid Jodhpuris', 'Quilted Jacket', 'Solid Belt', 'Wash & Whitening Serum',
                      'Waistcoat', 'Crop Jacket', 'Reversible Shorts', 'Kurta with Trousers', 'Hair Curler', 'Edt 70ml', 'Cropped Stretchable Jeans', 'Sports Sandals', 'Kurta with Sharara',
                      'Logo Fleece Hoodie', 'Soap 125g', 'Eau Toilette Perfume 120 ml', 'Bralette Bra', 'Eau De Toilette 90ml', 'Corn Styler', 'Design Heels', 'Regular Fit Trousers',
                      'Stretchable Striped Jeans', 'Blouson Dress', 'Non-Marking Shoes', 'Nightdress', 'Cushioned Monks', ' Lakshmishaped Brooch', 'Waist Top', 'Handcrafted Kulladh Set',
                      'Chino Shorts', 'Pencil Skirt', 'Self Design Pullover', 'Contemporary Cufflinks', 'Self Design Sweatshirt', 'Open Front Jacket', 'Cocktail Gown', 'Casual Shoes',
                      'Solid Briefs', 'Eau Toilette Spray Concentree Perfume 110ml', 'Semiformal Loafers', 'Tshirt with Shorts', 'Premium Puma-Whisper', 'Flicker Lacquerink Lip', 'Boyshorts',
                      'Artificial Bamboo Grass Plant With Pot', 'Matte Melt Liquid Lip', 'Track Pants', 'Printed Diwan Set', 'Finger Ring', 'Suede Loafers', 'Casual Driving Shoes', 'Boxers',
                      'Lacquerink Lip Shine', 'Robe with Embroidered Detail', 'Running T-shirt', 'Puffer Jacket', 'Leather Mojaris', 'Illuminati Briefs', 'Shoulder Bag', 'Tissue Holder',
                      'Leather Ballerinas', 'Longline Padded Jacket', 'Glow-in-the-Dark T-shirt', 'A-Line High-low Dress', 'Striper Sweater', 'Double Bed Cover with 2 Pillow Covers',
                      'Microliner Ink', 'A-Line Kurta', 'Formal Oxfords', 'Queen 06 Lipstick 3.7g', 'Table Placemat', 'Running Shoes', 'Solid Trousers', 'Striped Sneakers',
                      'Party Shirt', 'Anarkali Kurta', 'Facial Mist 150 ml', 'ModernMatte Powder Lipstick 4g', 'Shadow Liner Brow', 'Eye Definer', 'Running Rapid Dry Solid Regular Fit T-shirt',
                      'Ring Bracelet', 'Mozaic Shelf', 'Lace Solid', 'Stand Organizer', 'Shuffle Trunks', 'Tuxedo Suit', 'Lace Top', 'Striped Culottes', 'Embellished Palazzos',
                      'Artificial Flowers and Plants In Wood Square Pot', 'Striped Parallel Trousers', 'Lacquerink Lip', 'Puffer Jacket', 'Toiletry Bag', 'Ceramic Planters', 'Solid Clogs',
                      'InnerGlow CheekPowder 4 g', 'Adjustable Ring', 'Rayon Kurta', ' Lifestyle Regular Fit T-Shirt', 'Hand Carving Key Holder', 'Single-Breasted Pure Cotton Blazer',
                      'Square Cufflinks', 'Maang Tikka', 'Wrap Top', 'Foam Cleanser 150 ml', 'Basic Jumpsuit', 'Denim Shorts', 'Acrylic Scarves', 'Defence Creams', 'Aviator Sunglasses',
                      'Printed Dhoti Pants', 'Crop Sweatshirt','Top with Dhoti Pants', 'Embroidered Top', 'Striped Top', 'Oversized Studs', 'Slim Heels', 'Carina Slim Sneakers',
                      'Insulator Padded Jacket', 'Printed Sweatshirt', 'A-line Skirt', 'A-Line Skirt', 'Textured Heels', 'Clean Look Ankle-Length Jeans', 'Charcoal Peel Off Mask 100 g', 'Embellished Top',
                      'Breakfast Tray', 'Training T-shirt', 'Porcelain Bowl', 'Front-Open Sweatshirt', 'Synthetic Sandals', 'Pullover Sweatshirt', 'Printedshoulder Bag', 'Heeled Sandals',
                      'Liquid ArchEyeliner 0.4ml', 'Printed Jacket', 'Sustainable Kurta', 'Patterned Sweater', 'Self Design Sweater', 'Embellished Top with Palazzos', 'Trouders',
                      'Shirt Style Crop Top', 'Dipping Bowls', 'Pocket Square', 'Leather Driving Shoes', 'Long-line Jacket', 'Solid Sweatshirt', 'Stretchable Ankle Length Jeans',
                      'Striped Kitchen Towels', 'Solid Bomber', 'Analogue Watch', 'Analogue watch', 'Checked Top', 'Embroidered Saree', 'Double Bed Duvet Cover', 'Colourblocked Padded Jacket',
                      'Leather Brogues', 'Lace Saree', 'Sweatshirt with Pockets Detailing', 'Running Regular Fit T-shirt', 'Polo Collar T-Shirt', 'Single Bed Duvet Cover', 'Single-Breasted Suit',
                      'Crystal Watches', 'Owl Motif Cutlery Holder', 'Choker Necklace', 'Empire Dress', 'Formal Shirt', 'Formal Boots', 'Benetton Girls Black Blazer', 'Colourblocked Lightweight Jacket',
                      'Reversible Jacket', 'Blouson Top', 'Leather Formal Shoes', 'Ceramic Planter with Stand', 'Empire Top', 'Dial Basic Watch', 'Roma 68 OG Sneakers', 'Cotton Boxer',
                      'One Toe Flats', 'Artificial Tree Peony With Pot', 'Walking Shoes', 'Polo T-shirt', 'Bardot Top', 'Core Running Shoes', 'Single Solid Door Curtain', 'Satin Saree',
                      'Self-Striped Sweatshirt', 'Eau de Parfum 100ml', 'Detailing T-shirt', 'Culotte Jumpsuit', 'Sports T-shirt', 'Self-Design Trousers', 'Distressed Stretchable Jeans',
                      'Printed Top', 'Cardigan', 'Maxi Skirt', 'Analogue Wall Clock', 'Kurta with Skirt', 'Lehenga with Blouse', 'Run-High Risk', 'Sling Bag', 'Wrap Dress', 'A-Line Dress',
                      'Low-Rise Clean Look Jeans', 'Artificial Fruit Bonsai With Pot', 'Floral Print Saree', 'Cane Dome Wall Lamp', 'Drop Earrings', 'Shirt with Super Slim Collar',
                      'Room Slippers', 'Kaftan Top', 'V-Neck T-shirt', 'Denim Shirt', 'Round Neck T-shirt', 'Round Neck T-Shirt', 'Dress Material', 'Heeled Boots', 'Corduroy Shirt',
                      'Fold Wallet', 'Casual Jacket', 'Gel Lipstick 1.6 g', 'Striped A-Line Dress', 'Solid Saree', 'Striped Tunic', 'Solid Padded Jacket', 'Textured Loafers', 'Peg Trousers',
                      'Straight Palazzos', 'Large Trolley Suitcase', 'Single Door Curtain', 'Solid Salwar', 'Striped Playsuit', 'Checked Playsuit', 'Mid-Rise Clean Look Cropped Jeans',
                      'High-Rise Clean Look Cropped Jeans', 'Open Toe Flats', 'Cuff Bracelet', 'Handloom Dupatta', 'Analogue And Digital Watch', 'Leather Heels', 'Single Long Door Curtain',
                      'Bodycon Dress', 'Printed Heels', 'Regular Fit Hot Pants', ' Multistranded Necklace', 'Sustainable T-shirt', 'Mid-Rise Clean Look Acid Wash Stretchable Jeans',
                      'Cuff Straps Analogue Watch', 'Mid-Rise Clean Look Stretchable Crop Jeans', 'Solid Bardot Crop Top', 'Fitted Crop Top', 'Layered Top', 'Multistrand Necklace',
                      'Liquid Lipstick 01', 'Camisole', 'Turbo Shoes', 'Printed T-shirt', 'Liquid Eye Liner 03', 'Analog Watch', 'Crushed Effect Top', 'Cropped Trousers', 'Trumpet Skirt',
                      'Kurti with Dhoti Pants', 'Ceramic Lord Buddha Showpiece', 'Tussar Saree', 'Medium Trolley Suitcase', 'Self-Striped Sneakers', 'Printed Saree', 'Football Shoes',
                      'Artificial Milkweed With Pot', 'Artificial Water Plant With Pot', 'Solid Sandals', 'Linen Checked Saree', 'Liquid Lipstick 09', 'Solid T-shirt', 'Shoe-Style Sandals',
                      'Mid-Rise Low Distress Stretchable Jeans', 'Rectangle Sunglasses', 'Tailored Jacket', 'Eau de Parfum 75ml', 'Single Window Curtain', 'Napkin Holders', 'Buzz Backpack',
                      'Flared Palazzos', 'Pack of 2 White Bras', 'Monochrome T-shirt', 'Contemporary Chandbalis', 'Artificial Grass Bells With Pot', 'Ankle Length Socks', 'Calf-Length Socks',
                      'Clean Look Ankle Jeans', 'Square Sunglasses', 'Kitten Heels', 'Eau de Parfum 30ml', 'Oxidised Choker', 'Petite Treggings', 'Mini Torchiere Wall Lamp', 'Bow Tie',
                      'Printed Parallel Trousers', 'Caracal Suede SoftFoam+ Sneakers', 'Slim Fit Light Fade Stretchable Jeans', 'Artificial Coco Bonsai With Pot', 'Detail Top', 'Night suit',
                      'Analogue Octogonal Wall Clock', 'Legging', 'Boat Shoes', 'Artificial Rosemarry With Pot', 'Transparent Textured Wall Lamp', 'Kurta with Sharara & Dupatta', 'Jegging',
                      'Heavy Fade Stretchable Jeans', 'High-Rise Stretchable Cropped Jeans', 'Round Neck Boxy Goofy T-shirt', 'Mid-Rise Low Distress Jeans', 'Slim Fit Stretchable Jeans',
                      'Set Of 2 Code Platinum Body Perfumes', '12 Lipstick 3.7g', '11 Lipstick 3.7g', 'Hooded Padded Jacket', 'Kasavu Saree', 'Set Of 2 Code Bronze Perfumes 120 ml',
                      'Printed Pullover', 'Handheld Bag', 'Single Long Door Curtains', 'Solid Slip-Ons', 'Solid Slip-On', 'Leather Belt', 'Corduroy Trousers', 'Light Fade Stretchable Jeans',
                      'Pumps', 'Running Shorts', 'Kurta with Dhoti Pants & Dupatta', 'Bowling Cricket Shoes', 'Cotton T-shirt', 'Kurta with Dhoti Pants', 'Non Padded Bralette',
                      'Solid Pullover', 'MicroLiner Ink 0.08 gms', 'MicroLiner Ink 0.08 g', 'Stretchable cropped Jeans', 'Training T-Shirt', 'Wide Leg Cropped Palazzos', 'Ascot Cap',
                      'Bluetrack Pants', 'Open Knit Top with Shorts', 'Set Of 2 Tops', 'Brallete', 'Wooden Serving Tray', 'Pollux Mid-Top Sneakers','Link Bracelet', 'Cargo Shorts',
                      'Matte + Poreless Liquid Foundation - Natural Tan 320 30ml', 'Alcohol-Free Toner & Kajal with Sharpener', 'Open Knit Romper', 'Jeggings', 'Satchel', 'Peep Toe Flats',
                      'Antimicrobial Dupatta', 'Trousers with Belt', 'Denim Trousers', 'Bhagalpuri Saree', 'Casual Trousers', 'Stretchable Ankle-Length Jeans', 'Walking Sneakers',
                      'Tie-Wash Stretchable Jeans', 'Striped T-shirt with Solid Shorts', 'Cleansing Face Wash & Kajal with Sharpener', 'Kurta with Churidar', 'Lakshmi-Shaped Brooch',
                      'Low Distress Applique Stretchable Jeans', 'Innerwear Vests', 'Striped Sweater', 'Shift Dress', 'Clarity Night Gel & Face Care Kit', 'Layered Jumpsuit', 'Button Shrug',
                      'Knee Stretchable Jeans', 'Hem Stretchable Jeans', 'Bandhgala Slim Fit Suit', 'Glossy Formal Shoes', 'Printed Dress', 'Round Neck Dylan T-shirt', 'Contemporary Studs',
                      'Acrylic Magazine Organiser', 'Beanie', 'Skinny Fit Stretchable Jeans', 'Capri Jumpsuit', 'Slip-on Sneakers', 'Slip-On Sneakers', 'Innerglow Cheek Powder 4g',
                      'Kurta with Navy Blue Dhoti Pants & Dupatta', 'Bath Towel', 'Bulldog-Shaped Book Ends', 'Round Neck Slim Fit T-shirt', 'Studded Bracelet', 'Bowling Shoes', 'Silk Dress',
                      'Baseball Cap', '08 Lipstick 3.7g', 'Ceramics Cups', 'Mattifying Moisturiser & All-Day-Wear Kohl Kajal with Sharpner', 'Casual Crop Shirt', 'Solid Parallel Trousers',
                      '10 Lipstick 3.7g', 'Banarasi Saree', '23 Lipstick 3.7g','Detail Sneakers', 'Set of 2 Window Curtains', 'Set Of 2 Window Curtains', 'Colourblocked Jacket', 'Formal Brogues',
                      '15 Lipstick 3.7g', 'Fisherman Sandals', 'Blend Saree', 'Single-Breasted Formal Slim Fit Suit', 'Striped Saree', 'Sarong', 'Slim-Fit Bandhgala Suit', 'Formal Loafers',
                      'Liquid Lipstick 06', 'Platforms', 'Night Suit', 'Stretchable Frayed Hem Jeans', 'ModernMatte Powder Lipstick 4gms', 'Tassel Loafers', 'Cold-Shoulder Top',
                      'Open Front Shrug', 'Formal Monks', 'Suede Flats', 'Longline Parka Jacket', 'Illuminator Rose Gold 40 ml', 'Leather Flats','Owl Block Cutlery Holder', 'Self-Design Sweater',
                      'ModernMatte Powder Lipstick 4 g', 'Training Sweatshirts', 'Brand Logo Backpack', 'Handmade Shelf with Magnetic Key Holder', 'Mesh Sscaper Core Running Shoes',
                      'T-Strap Flats', 'Sleep Shirts', 'Training Shoes', 'Distressed Printed Jeans', 'Embellished Heels', 'Printed Tunic', 'Blend Woven Design Saree', 'Hood S-Shirt',
                      'Polka Dot Top', 'Printed Belt', 'Short Sleeve T-shirt', 'Lounge T-shirts', 'Ruffle Dress', 'Straight Kurti', 'Colourblocked Sweatshirt', 'Mesh Sneakers',
                      'Smash v2 Mid L Sneakers', 'Solid Sneakers', 'LayUp Sneakers', 'Cushioned Sneakers', 'Enamelled Jewellery Set', 'Gold-Plated Jewellery Set', 'Clean Look Stretchable Jeans',
                      'Meenakari Jewellery Set', 'Swan-Shaped Brooch', 'Checked Dupatta', 'Smash Perf Sneakers', 'Printed Slip-On', 'Spray-Dyed Sweater', 'Design Sneakers', 'Printed Sweater',
                      'IDP Sneakers', 'Acrylic Sweater', 'Regular-Fit Tuxedo', 'Jhumkas', 'Suede Sneakers', 'Eye Shadow Palette 5.2 g', 'Two Owls Ceramic Planter', 'Tiered Top',
                      'Drop-Waist Dress', 'Innerglow Cheek powder 4 g', 'Bootcut Trousers', 'KajalInk Artist- Shadow, Liner, Brow, 0.8gm', 'Key Holder', 'Colourblocked Sweater',
                      '1 Queen Bedsheet with 2 Pillow Covers', 'Ceramic Flower Vase', 'Palazzo Trousers', 'Suede Jacket', 'Desk Organizer', 'Solid Culottes', 'Sequinned Sneakers', 'Bath Mat',
                      'Striped Sandals', 'Solid Ballerinas', 'Cropped Sweatshirt', 'IDP Sneakers', 'Training Sweatshirt', 'Textured Sneakers', 'Woollen Sweater', 'Design Sandals',
                      'Door Curtain', 'Pacer EL IDP', 'Lifestyle Sweatshirt', 'Front-Open Sweater', 'Kurti with Skirt', 'Smash v2 L Plus Puma White-Puma Whi Sneakers', 'A-Line Midi Skirt',
                      'Solid Crop Top', 'Textured Sandals', 'Medium Backpack', 'Layered Playsuit', 'Layered Kurta', 'Solid Playsuit', 'Cream-Coloured Sneakers', 'Square Cushion Cover',
                      'Single Self- Design Window Curtain', 'Semiformal Slip-Ons', 'Sustainable Sweatshirt', 'Printed Playsuit', 'Checked Tunic', 'Embroidered Kurta', 'Ganesha Showpiece',
                      'Detangler Brush', '04 Lipstick 3.7g', 'Long Door Curtains', 'Tuxedo Blazer', 'Flared Sharara', 'Poly Georgette Saree', 'Design Cushion Covers', 'Washed Slim Jeans',
                      'Self-Design Tunic', 'Hooded Sweater', 'Crepe Saree', 'Print Top', 'Leheriya Saree', '16 Lipstick 3.7g', 'Chanderi Saree', 'Bootcut Jeans', 'Small Backpack',
                      'Stretchable Top', 'Outdoor Lamp', 'Dungarees', 'A-Line Tunic', 'Multi-Dial Watch', 'Single Door Curtains', 'Stretchable Ankle Length Jeans', 'Mules', 'Bandeau Bra',
                      'Overnighter Backpack', 'LiteRide Clogs', 'Reversible Bathmat', 'Leather Derbys', 'Peacoat-Quarry Sneakers', 'Textured Clutch', 'Face Statue', 'Rectangular Pillow Covers',
                      'Scoop Neck T-shirt', 'Rectangular Bath Rug', 'Table-Top Planter', 'Handpainted Flower Vase', 'Asymmetric Kurta', 'Embroidered Sweatshirt', 'Cotton Top', 'Flower Bales',
                      'Ceiling Lamp', 'Net Saree', 'Regular Top with Waist-Tie-ups', 'Clean Look Ankle Length Jeans', 'Pillow Covers', 'Bath Rug', 'Coffe Cup Set', 'Hooded Jacket',
                      'Strappy Dress', 'Regular Top', 'Poly Acrylic Bathmat', 'Mid-Top Heels', 'IDP Sneakers', 'High-Low Top', 'Kurti with Palazzos', 'Geometric Studs', 'Table Napkins',
                      'Wall Shelf', 'ID PSneakers', 'Block Heels', 'Flexracer SL Sneakers', 'Cotton Shirt', 'Strappyddress', 'Flatforms', 'LacquerInk Lip Shine 6 ml', 'Linen Cushion Covers',
                      'Lip Shine Optic Rose 309', 'MicroLiner Ink Eyeliner 0.08 gms', 'Coffee Cup Set', 'Synthetic Leather Mid-Top Sneakers', 'Smash v2 Peacoat Sneakers', 'Basic 2.0 Sneakers',
                      'Declan 2.0 Sneakers', 'Lace-Up Sneakers', 'Flexracer Sneakers', 'Pullover Sweater', 'Nucleus Run Peacoat-Silver Sneakers', 'VariKnit Sneakers', 'Multistrand Bracelet',
                      'Code Bronze Perfumes 120 ml', 'Mid-Top Sneakers', 'Runner Premium SoftFoam+ Sneakers', 'Runner V2 Sneakers', 'Urban Graphicster Sneakers', 'Smash V2 Sneakers',
                      'Striped CottonT-shirt', 'Racing Evo Cat II Sneakers', 'Running Sweatshirt', 'Aeon Play Sneakers', 'Canim Idp SoftFoam+ Sneakers', 'Electron Street Sneakers',
                      'Round Neck DYLAN T-shirt', 'Vista Sneakers', 'Clarifying Concentrate & Kajal with Sharpener', 'Suede SoftFoam+ Sneakers', 'Smash BFF P Sneakers', 'Astro Kick Sneakers',
                      'LayUp SoftFoam +Sneakers', 'Heavy Fade Jeans', 'Mermaid Yoga Figurine Showpiece', 'Face Mist & Kajal with Sharpener', 'Running Jacket', 'Pirelli V2 Sneakers',
                      'Solid Trunks', 'STORM ORIGIN Sneakers', 'Body Perfume', 'Super Stay Lip Gloss 7ml', 'Pacer Next 2.0 Sneakers', 'Pure Cotton Saree', 'ST Runner v2 Full Sneakers',
                      'Sukhasana Yoga Showpiece', 'Leather Passport Holder', 'Geo Floating Table-Top Photo Frame', 'Polo Collar Tropical T-shirt', 'Runner Premium Sneakers', 'Solid Dupatta',
                      'One-Shoulder Velvet Finish Crop Top', 'Purse Clutch', 'Cow Face Yoga Figurine', 'Bow Yoga Figurine', 'Smash Vulc SoftFoam+ Sneakers', 'Formal Linen Trousers',
                      'Poreless Liquid Foundation - Classic Ivory 120 30ml', 'Knit 2.0 Sneakers', 'Gum Sneakers', 'Hedgetopia Desk Plant With Pot', 'Cell Venom Alert Sneakers',
                      'Stretchable Embellished Jeans', 'Limitless Lean Modern Sneakers', 'Fold Leather Wallet', 'Kart Cat X Sneakers', 'Striped Mid-Rise Jeans', 'Ultra II Sneakers',
                      'Maternity Kurta', 'Yoke Jumpsuit', 'Embellished Backpack', 'Matte Retro Red Lipstick 004', 'Smash BFF Sneakers', 'Round Neck Yoga T-shirt', 'Shaper Brief ',
                      'Handcrafted Cocktail Ring', 'Purse', 'Topiary Desk Plant', 'Adela X Sneakers', 'Nymeria Wolf Showpiece', 'Smash v2 Buck Sneakers', 'Ultra SoftFoam+ Sneakers',
                      'Acrylic Reindeer Book Ends', 'Runner V2 Nl Sneakers', 'Axis Sneakers', 'Matte Lipstick - Seductive Sienna 015 4.2 g', 'Hood T-shirt', 'Short Sleeve T-Shirt',
                      'Kurta with Zari Work', 'Slim Fit Formal Suit', 'Eau de Toilette 100ml', 'Single-Breasted Casual Pure Cotton Blazer', 'Stretchable Ankle-Length Jeans',
                      'Round Neck Lounge T-shirt', 'Corded Epilator', 'Wayfarer Sunglasses', 'Embellished Sandals', 'Stretchable Jogger Jeans', 'Dungree', 'Silk Epilator', 'Sleep Shirt',
                      'Brush with ThermoProtect', 'Peg Linen Trousers', 'Lounge T-shirt', 'Knitted Sweatshirt Dress', 'Saree With Blouse', 'Printed Culottes', 'Checked Trousers',
                      'Two-Piece Suit', 'Fringed Top', 'Off-Shoulder Playsuit', 'Square Desk Organiser', 'Driving Shoes', 'Yoga Pants', 'Charm Bracelet', 'Round Desk Organiser',
                      'Polo Collar Slim-Fit T-shirt', 'Ruffle Saree', 'Lehenga & Blouse with Dupatta', 'Striped Trousers', 'Animal Print Saree', 'Single-Breasted Bandh Gala Suit',
                      'Rectangle Serving Tray', 'Colourblocked Knitted Sweatshirt', 'Single-Breasted Two Piece Suit', 'Rectangular Foldable Desk Organiser', 'Satin-Hair 3 Hair Straightener',
                      'Embroidered Shorts', 'Diamond 2-in-1 Shampoo and Body Wash 250 ml', 'Colorblock Logo Polo T-Shirt', 'Styled Back Top', 'Floral Print Culottes', 'Kurta With Palazzo',
                      'Rectangular Desk Organiser', 'Net Flared Skirt', 'Slim Fit T-shirt', 'Leather Travell Pouch', 'Hath Gadi with Glass Bowls', 'Mini Skirt', 'Genuine Leather Laptop Bag',
                      'Genuine Leather Toiletry Pouch', 'Skateboard Print Pullover', 'Facial Epilator & Cleansing System', 'SET 9 Shades Eyeshadow Pallete', 'Solid Blazer', 'A-Line Kurti',
                      'Body suits', 'Iron BBQ Serving Platter', 'Woven Design Dupatta', 'Checked Casual Reversible Shirt', 'Floral Print Off Shoulder Playsuit', 'Colourblocked Heels',
                      'Cigarette Linen Trousers', 'Herbal Onion Hair Growth Oil with Amla For Hairfall Control Greying 220 ml', 'Gym Shoes', 'Graphic Polo Shirt', 'Modern Pattern Rug',
                      'Washed Denim Mini Straight Skirt', 'High-Low Tunic', 'Micro Ditsy Printed Shirt', 'Bandhani Chiffon Sustainable Saree', 'Super Slim Fit Suit', 'Colourblocked Sneakers',
                      'Premium Abstract Pattern Rug', 'Shaper Briefs', 'Lavender Bamboo Grass Wooden Pot', 'Printed Mobile & Tablet Pop Holder', 'Innerglow Cheek powder 4g', 'Dial Watch',
                      'Laptop Bag', 'Floral Lingerie Set LA1-FLOWER', 'Woven Design Ballerinas', 'Printed Reversible Peplum Jacket', 'Kundan Stone-Studded Jewellery Set', 'Sports Bluetooth Wireless Earphones',
                      'Dawn Redwood Plant with Pot', 'Premium Floral Pattern Area Rug', 'Hath Gadi Dip with Bowls', 'Wired Earphones with Sports Fit Stretch Resistance', 'Veere Rakhi',
                      'Self Design Contemporary Fit Single Breasted Bandhgala Blazer', 'Lace Lingerie Set', 'Maxi Flared Skirt', 'Artificial Stone-Studded Anklet', 'Smash v2 Vulc Sneakers',
                      'Graphic Print Tank Studio Top', 'Semi Sheer Straight Skirt', 'Wraparound Rakhi', 'Patiala Salwar', 'Striped Sweatshirt with Printed Detail', 'Classic Studs',
                      'Single-Breasted Formal Pure Cotton Blazer', 'Batman Design Cufflinks', 'Wooden Paisley Shaped Rakhi', 'Artificial Plants Grass Bells with Pot', 'Suede Sandals',
                      'Checked A-Line Mini Dress', 'iPhone X Glass Case Cover', 'Printed Detail Dhoti Salwar', 'Saturday Rise Up N Run Solid Shorts', 'Spiderman Cufflinks',
                      'Artificial Rosemerry Flower with Pot', 'Woven Super Slim Fit Bandhgala Suit', 'Plastic Handcrafted Rakhi', 'Checked Linen Single-Breasted Slim Fit Blazer',
                      'Carnation with Wooden Pot', 'Solid Loafers', 'Woven Design Mysore Silk Saree', 'Leather Boots', 'Solid Treggings', 'Styled Back Crop Top', 'Solid Kurti',
                      'LXCON 94 Sneakers', 'Floral Pattern Rug', 'Suede Heels', 'Mermaid Sequinned Sweatshirt', 'Embellished Sweatshirt', 'Scooter Shaped Cufflinks', 'Solid Cropped Palazzos',
                      'Hooded Reversible Bomber', 'Artificial Yellow Lily Flower with Pot', 'Woven Design Banarasi Kota Saree', 'Distressed Pattern Area Rug', 'Mukaish Work Dupatta',
                      'Single-Breasted Urban Fit Solid Suit', 'Leather Wraparound Bracelet', 'Artificial Formosan Plant in Square Step Pot', 'Round Sunglasses', 'Oversized Sunglasses',
                      'Stretchable Acid Wash Cropped Jeans', 'Gemstone Studded Cufflinks', 'Woven Design Patola Saree', 'Impact Bra', 'Textured Ballerinas', 'Quilted Backpack',
                      'Striped Sweatshirt', 'Zip Around Wallet', 'Gazelle Sneakers', 'Studded Heels', 'Printed Sustainable Pure Cotton Dupatta', 'Self Design Drop Waist Dress',
                      'Checked Pure Cotton Blazer', 'Cropped Drop Crotch Trousers', 'Artificial MilkWeed Flowers with Pot', 'Super Stay Lip Gloss 7 ml', 'Cropped Dhoti Pants',
                      'Shirt Denim Dress', 'Artificial Mini Carnation Grass Flower Plant Carnation Flowers with Pot', 'Rakhee', 'Camouflage Printed Reversible Bomber', 'Oval Sunglasses',
                      'Speed Flexweave Training Soes', 'Bro Hand-Embroidered Rakhi', 'Partywear Shirt', 'Colourblocked Duffel Bag with Printed Detail', 'Chronograph Watch',
                      'A-Line Fusion Kurta', 'Sequin Velvet Finish Sweatshirt', 'Printed Shirt Tunic', 'Reversible Bomber', 'Hooded Bomber', 'Stretchable Ombre Jeans', 'Ceramic Handi or Pot',
                      'Kurta with Attached Pallu', 'Khakis in Slim Fit with GapFlex', 'Printed Blazer', 'Leather Formal Derby', 'Nasa Printed Round Neck Half Sleeve T-shirt',
                      'Round Neck Knitted T-shirt', '4-Pieces Solid Ceramic Dessert Stand Set', 'Candy Stripe Top', 'Leather Messenger Bag', 'Straight Cotton Kurta', 'Striped Belt',
                      'Ruffle Detail Sweater', 'Leather Card Holder', ' Printed Sneakers', 'Printed Crop Top with Skirt & Shrug', 'Solid Sharara', 'Geometric Woven Shaggy Carpet',
                      'Kurti with Sharara & Dupatta', 'Striped Cropped Palazzos', 'Printed Flared Midi Skirt', 'Tiny Turtle Serving Bowl with Lid', 'Design Straight Handloom Kurta',
                      'Colourblocked Belt', 'Tshirt for Women', 'Woollen Blazer', 'Dual Colour Wooden Serving Bowl with Lid', 'Striped Longline Shirt', 'Leather Solid Messenger Bag',
                      'Salt & Pepper Shaker Set', 'Printed Stole', 'Embroidered Detail Dhoti Pants', 'Paisley Floral Owl iPhone 8 and SE Case', 'Leather Formal Slip-On Shoes', 'Track Pant',
                      'Wood Chopping Board/ Serving Platter', 'Printed Longline Shrug', 'Pathani Kurta', 'Stone Studded Jewellery Set', 'Pendant Set', 'Printed Backpack', 'Flatform Sneakers',
                      'Dyed Top', 'Satin Finish Top', 'Leather Formal Slip On Shoes', ' Lehenga & Blouse', 'Printed Straight Silk Blend Kurta', 'Khakis in Skinny Fit with GapFlex',
                      'Two Fold Genuine Leather Wallet', 'Cat Lady Printed iPhone 8 and SE Case', 'Set of 2 Pie Dishes', 'Gown with Peplum Jacket', 'Printed Ballerinas', 'Cateye Sunglasses',
                      'Dhoti Pants', 'Self Design Trousers', 'Set of 6 Eliezabeth Purple+Pantograph Wine Glasses 350ml', 'Printed Crop Top with Palazzos & Ethnic Jacket', 'Phase Backpack',
                      'Solid Pure Cotton Dupatta', 'Enamelled Brooch', 'A-Line Ethnic Dress', 'Lehenga & Kurta', 'Cat Lady Printed iPhone X Case', 'Woven-Design Shawl', 'Graphic Backpack',
                      'Printed Straight Winter Kurta', 'Striped Microfibre Runner', 'Printed Layered Straight Winter Kurta', 'Printed Palazzos', 'Striped Runner', 'Self Design Hobo Bag',
                      'Artistic Shaped Tasselled Pendant With Chain', 'Printed Open Front Longline Shrug', 'Hooded Slim Fit Sweatshirt', 'Printed Flared Cropped Palazzos', 'Printed Pullover Sweater',
                      'Embellished Rectangle Cushion Covers', 'Set of 2 Self Design Rectangle Cushion Covers', 'Straight Winter Kurta', 'Colourblocked Ballerinas', 'Printed Maxi Flare Skirt',
                      'Indigo Knitted Winter Kurta', 'Circular Tasselled Pendant With Chain', 'Casual Jumpsuit', 'Knitted Printed Layered Winter Kurta', 'Tassel Detail Backpack', 'Sequinned Tank Top',
                      'Colourblocked Round Neck Chicago Bulls T-shirt', 'Textured Laptop Backpack', 'Brand Logo Originals Backpack', 'Plunge Push-Up Bra', 'Accessory Gift Set', 'Crop Fitted Top',
                      'Set of 2 Ethnic Motifs Rectangle Cushion Covers', 'Self Design Jacket', 'Regular Fit Blazer', 'Graphic Originals Backpack', 'Printed Straight Cropped Palazzos',
                      'Design A-Line Winter Kurta', 'Cropped Treggings', 'Brand Logo Deck Backpack', 'Woven Design Shawl', 'Printed Lightweight Jacket', 'Textured Hobo Bag', 'Push-Up Bra',
                      'Shirred Tank Top', 'Velvet Finish Self Design Longline Button Shrug', 'Brand Logo Sole Backpack', 'Dyed Round Neck Manchester City FC T-shirt', 'Self Design Shrug',
                      'Snakeskin Print Leather Flat Shoes', 'Forerunner 945 Smartwatch', 'Colourblocked Cell Backpack', 'Self Design Shimmered Waterfall Shrug', 'Solid Leather Backpack',
                      'Set of 2 Abstract Rectangle Cushion Covers', 'Set of 2 Textured Rectangle Cushion Covers', 'Solid Slim Fit Sweatshirt', 'Solid Overcoat', 'Melange Solid Button Shrug',
                      'Graphic Beta Laptop Backpack', 'Lifestyle Laptop Textured Backpack', 'Checked Trench Coat', 'Printed Knitted Sweatshirt', 'Textured Slip-On', 'ST Runner v2 Full Sneakers',
                      'Textured Synthetic Patent Ballerinas', 'Colourblocked Slim Fit Sweatshirt', 'Printed Straight Angrakha Kurta', 'Brand Logo Laptop Backpack', 'Geometric Backpack',
                      'Floral Printed Keyhole Neck Kurta', 'Slim-Fit Churidar', 'Self-Checked Pure Cotton Dupatta', 'Textured Passport Holder', 'Round Neck Athleisure T-shirt', 'Hobo Bag',
                      'Replica Neck T-shirt', 'Ruffled Checked Saree', 'Printed Straight Chambray Kurta', 'Chambray Palazzos', 'Printed Sandals', 'Heart-Shaped Necklace', 'Kundan Polki Pearls Jewellery Set',
                      'Original Straight Fit Animal Print Parallel Trousers', 'Cropped Parallel Trousers', 'Accordian Pleated Parallel Trousers', 'Casual Single Breasted Blazer', 'Shoeliner Socks',
                      'Colourblocked Round Neck Chicago Bull T-shirt', 'Triangular Enamelled Studs', 'Layered Printed A-Line Winter Kurta', 'Suede Horsebit Loafers', 'Fanwear Backpack',
                      'Compress Performance Shorts', 'Self Design Overcoat', 'Printed Pure Cotton Dupatta', 'Sheen Effect Dupatta', 'Printed Flared Skirt', 'Printed Woolen Carpet', 'Satin Robe',
                      'Self Design Straight Winter Palazzos', 'Handmade Woolen Carpet', 'Washed Regular Fit Denim High Rise Shorts', 'Printed Crop Top', 'Solid Trunk', 'Printed Carpet',
                      'Printed Hand Tufted Wool Carpet', 'Push-Up Stick-On Bra', 'Straight Cropped Palazzos', 'Flared Cropped Palazzos', 'Graphic Academy Backpack', 'Beaded Jewellery Set',
                      'Straight Cropped Palazzos', 'Enamelled Designer Jewellery Set', 'Printed Handmade Anti-Skid Woolen Carpet', 'Poly Georgette Fringed Saree', 'Solid Jacket', 'Semiformal Derbys',
                      'Geometric Print Laptop Backpack', 'Printed Hand Tufted Woolen Carpet', 'Skinny-Fit Treggings', 'Musician Doll Handmade Decorative Showpiece', 'Solid Sweater', 'Cropped Fitted Top',
                      'Multi-Stranded Necklace', 'Pleated Top', 'Large Backpack', 'ST Runner v2 Sneakers', 'Zaire Minimal Necklace', 'Bandhani Saree', 'Bedside Table Lamp', 'Princess Coat',
                      'Floral Stone Studs', 'Embroidered Detail Sweatshirt', 'Checked Saree', 'Stone-Studded Jewellery Set', 'Basket Heart Reinvent Sneakers', 'Future Runner Sneakers',
                      'Espadrilles', 'Square Studs', 'Laptop Backpack', 'Houndstooth Pattern Trousers', 'Sequin Jeans with Fantastiflex', 'CITY SLEEK SS DRI-FIT Top', 'Smash v2 Vulc SL Sneakers',
                      'Lightweight Sweater', 'Run Sneakers', 'Textured Top', 'Printed Trunks', 'Longline Overcoat', 'Wireless Speaker with Rugged IPX5', 'Western Designer Jewellery Set',
                      'Skinny Fit Treggings', 'Chambray Top', 'Open Front Casual Pure Cotton Blazer', 'Tunic Shirt', 'ROZAN Sandals', 'Enamelled Choker Pearls Jewellery Set', 'Formal Slip-Ons',
                      'Striped Crop Top', 'Taselled Loafers', 'Slip-Ons Shoes', 'Floral Print Crop Top', 'Rectangular Anti-Skid Coir Doormat', 'Printed Back Sweatshirt', 'Pack of 3 Solid Black Briefs',
                      'Musician Doll Handcrafted Showpiece', 'Textured Brogues', 'Kundan Jewellery Set', 'Heavy Winter 150 GSM Double Bed Comforter', 'Reversible Padded Jacket', 'Casual Derbys',
                      'Polki Designer Jewellery Set', 'Handcrafted Kundan Polki Ring', 'Premium Coir and Rubber Printed Mat', 'Temple Jewellery Set', 'Casual Blazer', 'Artificial Stone-Studded Anklet',
                      'Oxidised Necklace', 'Layered Necklace', 'Formal Slip-Ons', 'Formal Derbys', 'Self-Striped Fitted Top', 'Solid Fitted Top', 'Single-Breasted Formal Slim Fit Suit', 'Turin II NL Sneakers',
                      'Ethnic Motifs AC Room 120 GSM Reversible Single Bed Dohar', 'Geometric Reversible AC Room 110 GSM Single Bed Dohar', 'Ethnic Motifs AC Room 120 GSM Single Bed Dohar',
                      'Oxidised Gold-Plated Necklace', 'Single-Breasted Formal Slim Fit Suit', 'Single-Breasted Slim Formal Suit', 'Floral AC Room 120 GSM Single Bed Dohar', 'Solid Derbys',
                      'Geometric AC Room 110 GSM Single Bed Dohar', 'Crescent Shaped Chandbalis', 'Floral Reversible AC Room 110 GSM Single Bed Dohar', 'Wash Stretchable Jeans', 'Eyelet Top',
                      'Beaded Floral Chandbalis', 'Metal Handcrafted Necklace', 'Printed Hand Painted Table Lamp', 'Robe With Embroidered Detail', 'Set Of 2 Toilet Brush With Holder', 'Girlfriend Jeans',
                      'Warli Painting Wall Candle Stand', 'Yoga Seamless Shorts', 'One-Shoulder Top', 'Colourblocked Top', 'Wide-Leg Palazzos', 'Clean Stretchable Jeans', 'Melange Shorts',
                      'AC Room 110 GSM Single Bed Quilt', 'Beaded & Handcrafted Necklace', 'Solid Sporty Jacket', 'Regular Fit Stretchable Jeans', 'Striped Stretchable Jeans', 'Stretchable Jeans', ' Open-Toe Flats',
                      'Set of 2 Orange Printed Window Curtains', 'Set of 2 Blue & White Printed Window Curtains', 'Set of 2 Orange & Magenta Printed Window Curtains', 'Set of 2 Printed Window Curtains',
                      'Pack of 3 Black Briefs', 'Set of 2 Printed Window Curtains', 'Set of 2 Printed Room Darkening Window Curtains', 'Hooded Slim Fit Sweatshirt', 'Crystals and Flower Petal Stones Metal Necklace',
                      'Long Metal Necklace', 'Sign Necklace', 'Handcrafted Necklace', 'Shimmer Shirt', 'Platform Heels', 'Non-Wired Bra', 'Lace Inserts Top', 'Embellished Kurta Set', 'Enamelled Floral Chandbalis',
                      'Single Jacquard Window Curtain', 'Orosa Sculpting Eyeshadow', 'Insulator PU Bomber', 'Plant With Pot', 'Striped High Neck T-shirt', 'Detail Sweatshirt', 'Smash Platform Leather SoftFoam+ Sneakers',
                      'ST Runner v2 Full Sneakers', 'Turin II SoftFoam+ Sneakers', 'Pacer Next Excel Core SoftFoam + Sneakers', 'Logo Chest-Stripe Long Sleeve Polo T-Shirt', 'Escaper Core SoftFoam + Sneakers',
                      'Training Regular Fit T-shirt', 'Empire Sustainable Top', 'Insulator Bomber', 'Crescent Shaped Chandbalis']

# Fungsi untuk menyederhanakan nama produk tanpa batasan kata dan tanpa konversi ke huruf kecil
def simplify_product_name(name):
    for category in product_categories:
        # Cek jika kategori ditemukan di dalam nama produk tanpa batasan kata dan tanpa konversi ke huruf kecil
        if category in name:  # Mengecek apakah kategori ada dalam nama produk
            return category.title()  # Mengembalikan kategori produk yang ditemukan
    return 'Other'  # Jika tidak ditemukan, beri label 'Other'

# Terapkan fungsi ke kolom ProductName
df['SimplifiedProductName'] = df['ProductName'].apply(simplify_product_name)

# Menampilkan beberapa hasil pemangkasan nama produk
df[['ProductName', 'SimplifiedProductName']]
# Out:
#                                              ProductName  \
# 0      DKNY Unisex Black & Grey Printed Medium Trolle...
# 1      EthnoVogue Women Beige & Grey Made to Measure ...
# 2      SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3      Raymond Men Blue Self-Design Single-Breasted B...
# 4      Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...                                                  ...
# 12485  Laceandme Black Lace Non-Wired Lightly Padded ...
# 12486  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487                 Mochi Women Gold-Toned Solid Heels
# 12488  612 league Girls Navy Blue & White Printed Reg...
# 12490  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#                 SimplifiedProductName
# 0                  Medium Trolley Bag
# 1               Kurta Set With Jacket
# 2           Stretchable Cropped Jeans
# 3      Single-Breasted Bandhgala Suit
# 4                        Casual Shirt
# ...                               ...
# ...

# %%
print("Jumlah unik:", df['ProductName'].nunique())
# Out:
# Jumlah unik: 10047

# %%
df.head(5)
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)                                        Description  \
# 0  Unisex        11745  Black and grey printed medium trolley bag, sec...
# 1   Women         5810  Beige & Grey made to measure kurta with churid...
# 2   Women          899  Pink coloured wash 5-pocket high-rise cropped ...
# 3     Men         5599  Blue self-design bandhgala suitBlue self-desig...
# 4     Men          759  Brown and off-white printed casual shirt, has ...
#
#   PrimaryColor           SimplifiedProductName
# ...

# %%
keyword = "Medium "
filtered_df = df[df['ProductName'].str.contains(keyword, case=False, na=False)]
filtered_df
# Out:
#       ProductID                                        ProductName  \
# 0      10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 86     10017427               DKNY Unisex Black Medium Trolley Bag
# 178    10017441              DKNY Unisex Silver Medium Trolley Bag
# 382    10017457               DKNY Unisex Black Medium Trolley Bag
# 389    10017453              DKNY Unisex Purple Medium Trolley Bag
# 478    10017409               DKNY Unisex Black Medium Trolley Bag
# 504    10017443              DKNY Unisex Silver Medium Trolley Bag
# 853    10017419  DKNY Unisex Gold-Toned & White Striped Medium ...
# 2105   10051483    Calvin Klein Unisex Red Medium Trolley Suitcase
# 3290   10105861  Genie Women Black Printed 17inches Medium Lapt...
# 3331   10105863  Genie Women Blue Printed 16 inches Medium Back...
# 3751   10101529  Genius Unisex Blue & Blue  Printed 17inches Me...
# 4012   10105897  Genie Women Blue Geometric Print 16 inches Med...
# ...

# %%
df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2       10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...          ...                                                ...
# 12485   10261595  Laceandme Black Lace Non-Wired Lightly Padded ...
# 12486   10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12488   10261607  612 league Girls Navy Blue & White Printed Reg...
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  \
# 0             DKNY  Unisex        11745
# 1       EthnoVogue   Women         5810
# ...

# %%
def gabungkan(row):
    return f"{row['Gender']} {row['SimplifiedProductName']} {row['PrimaryColor']} {row['ProductBrand']}"

df['text_combined'] = df.apply(gabungkan, axis=1)

# %%
(df['text_combined'])
# Out:
# 0                    Unisex Medium Trolley Bag  Black DKNY
# 1            Women Kurta Set With Jacket  Beige EthnoVogue
# 2             Women Stretchable Cropped Jeans  Pink SPYKAR
# 3          Men Single-Breasted Bandhgala Suit Blue Raymond
# 4                             Men Casual Shirt  White Parx
#                                ...
# 12485                    Women Bralette Bra  Red Laceandme
# 12486    Men Clean Look Stretchable Jeans  Black Pepe J...
# 12487                        Women Solid Heels  Gold Mochi
# 12488                   Girls Denim Shorts Blue 612 league
# 12490            Men Polo Collar T-Shirt  Black Pepe Jeans
# Name: text_combined, Length: 11597, dtype: object

# %%
# prompt: buatkan codee untuk prrint isi dari tabel text_combined dengan ProductID[10017413]

# Temukan baris dengan ProductID 10017413
row_10017413 = df[df['ProductID'] == 10017833]

# Periksa apakah baris ditemukan
if not row_10017413.empty:
    # Dapatkan nilai 'text_combined' dari baris yang ditemukan
    text_combined_10017413 = row_10017413['text_combined'].iloc[0]

    # Cetak nilai 'text_combined'
    text_combined_10017413
else:
    print("ProductID 10017413 tidak ditemukan dalam DataFrame.")
text_combined_10017413
# Out:
# 'Men Casual Shirt  White Parx'

# %%
df.head(5)
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)                                        Description  \
# 0  Unisex        11745  Black and grey printed medium trolley bag, sec...
# 1   Women         5810  Beige & Grey made to measure kurta with churid...
# 2   Women          899  Pink coloured wash 5-pocket high-rise cropped ...
# 3     Men         5599  Blue self-design bandhgala suitBlue self-desig...
# 4     Men          759  Brown and off-white printed casual shirt, has ...
#
#   PrimaryColor           SimplifiedProductName  \
# ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt_tab')
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
# # prompt: buatkan code untuk melihat Perhitungan TF IDF dari hasil tokenisasi di bawa ini secara detail, mulai dari TF, IDF, sampaai TF-IDF
# # "
# # ['unisex', 'dkni', 'unisex', 'black', 'grey', 'print', 'medium', 'trolley', 'bag', 'black', 'dkni']
# # ['women', 'ethnovogu', 'women', 'beig', 'grey', 'made', 'measur', 'custom', 'made', 'kurta', 'set', 'jacket', 'beig', 'ethnovogu']
# # ['women', 'spykar', 'women', 'pink', 'alexa', 'super', 'skinni', 'fit', 'highris', 'clean', 'look', 'stretchabl', 'crop', 'jean', 'pink', 'spykar', 'crop', 'jean', 'pink', 'spykar']
# # ['men', 'raymond', 'men', 'blue', 'selfdesign', 'singlebreast', 'bandhgala', 'suit', 'blue', 'raymond'],
# # ['men', 'parx', 'men', 'brown', 'offwhit', 'slim', 'fit', 'print', 'casual', 'shirt', 'white', 'parx']
# # "

# from sklearn.feature_extraction.text import TfidfVectorizer

# # Contoh data tokenisasi (dari hasil sebelumnya)
# tokenized_docs = [
#     ['unisex', 'dkni', 'unisex', 'black', 'grey', 'print', 'medium', 'trolley', 'bag', 'black', 'dkni'],
#     ['women', 'ethnovogu', 'women', 'beig', 'grey', 'made', 'measur', 'custom', 'made', 'kurta', 'set', 'jacket', 'beig', 'ethnovogu'],
#     ['women', 'spykar', 'women', 'pink', 'alexa', 'super', 'skinni', 'fit', 'highris', 'clean', 'look', 'stretchabl', 'crop', 'jean', 'pink', 'spykar', 'crop', 'jean', 'pink', 'spykar'],
#     ['men', 'raymond', 'men', 'blue', 'selfdesign', 'singlebreast', 'bandhgala', 'suit', 'blue', 'raymond'],
#     ['men', 'parx', 'men', 'brown', 'offwhit', 'slim', 'fit', 'print', 'casual', 'shirt', 'white', 'parx']
# ]

# # Menggabungkan kembali token menjadi string untuk TfidfVectorizer
# corpus = [" ".join(doc) for doc in tokenized_docs]

# # Inisialisasi TfidfVectorizer
# # Sublinear_tf=True untuk menggunakan 1 + log(tf)
# # norm='l2' untuk normalisasi L2
# # smooth_idf=True untuk menghindari pembagian dengan nol
# vectorizer = TfidfVectorizer(sublinear_tf=True, norm='l2', smooth_idf=True)

# # Melakukan fit dan transform pada korpus
# tfidf_matrix = vectorizer.fit_transform(corpus)

# # Mendapatkan daftar kata-kata (fitur)
# feature_names = vectorizer.get_feature_names_out()

# # Mendapatkan nilai IDF untuk setiap kata
# idf_values = vectorizer.idf_

# # Membuat dictionary untuk mapping kata ke nilai IDF
# word_idf = dict(zip(feature_names, idf_values))

# print("--- Detail TF-IDF ---")

# # Iterasi melalui setiap dokumen dan kata untuk menampilkan detail
# for i, doc in enumerate(tokenized_docs):
#     print(f"\nDokumen {i+1}:")
#     # Mendapatkan matriks TF-IDF untuk dokumen saat ini
#     doc_tfidf = tfidf_matrix[i].toarray()[0]

#     # Membuat dictionary untuk mapping kata ke nilai TF-IDF dalam dokumen ini
#     word_tfidf = dict(zip(feature_names, doc_tfidf))

#     # Hitung TF (Term Frequency) secara manual untuk demonstrasi
#     word_counts = {}
#     for word in doc:
#         word_counts[word] = word_counts.get(word, 0) + 1
#     total_words_in_doc = len(doc)
#     word_tf = {word: count / total_words_in_doc for word, count in word_counts.items()}


#     # Tampilkan detail TF, IDF, dan TF-IDF untuk setiap kata unik dalam dokumen
#     unique_words_in_doc = sorted(list(set(doc))) # Urutkan untuk tampilan yang konsisten
#     for word in unique_words_in_doc:
#         tf = word_tf.get(word, 0)
#         idf = word_idf.get(word, 0) # Ambil IDF dari dictionary IDF global
#         tfidf = word_tfidf.get(word, 0) # Ambil TF-IDF dari matriks TF-IDF

#         print(f"  Kata: '{word}'")
#         print(f"    TF (Term Frequency): {tf:.4f} ({word_counts.get(word, 0)} / {total_words_in_doc})")
#         print(f"    IDF (Inverse Document Frequency): {idf:.4f}")
#         print(f"    TF-IDF: {tfidf:.4f}")


# # Opsional: Menampilkan matriks TF-IDF dalam DataFrame Pandas
# df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)
# print("\n--- Matriks TF-IDF Lengkap ---")
# df_tfidf

# %%
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer

# # Data tokenisasi
# tokenized_docs = [
#     ['unisex', 'dkni', 'unisex', 'black', 'grey', 'print', 'medium', 'trolley', 'bag', 'black', 'dkni'],
#     ['women', 'ethnovogu', 'women', 'beig', 'grey', 'made', 'measur', 'custom', 'made', 'kurta', 'set', 'jacket', 'beig', 'ethnovogu'],
#     ['women', 'spykar', 'women', 'pink', 'alexa', 'super', 'skinni', 'fit', 'highris', 'clean', 'look', 'stretchabl', 'crop', 'jean', 'pink', 'spykar', 'crop', 'jean', 'pink', 'spykar'],
#     ['men', 'raymond', 'men', 'blue', 'selfdesign', 'singlebreast', 'bandhgala', 'suit', 'blue', 'raymond'],
#     ['men', 'parx', 'men', 'brown', 'offwhit', 'slim', 'fit', 'print', 'casual', 'shirt', 'white', 'parx']
# ]

# # Gabungkan token ke bentuk string
# corpus = [" ".join(doc) for doc in tokenized_docs]

# # Inisialisasi TF-IDF Vectorizer
# vectorizer = TfidfVectorizer(sublinear_tf=True, norm='l2', smooth_idf=True)
# tfidf_matrix = vectorizer.fit_transform(corpus)
# feature_names = vectorizer.get_feature_names_out()
# idf_values = vectorizer.idf_
# word_idf = dict(zip(feature_names, idf_values))

# # Simpan matriks TF-IDF sebagai DataFrame
# df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# # List untuk menyimpan detail per kata (TF, IDF, TF-IDF)
# detail_rows = []

# for i, doc in enumerate(tokenized_docs):
#     doc_tfidf = tfidf_matrix[i].toarray()[0]
#     word_tfidf = dict(zip(feature_names, doc_tfidf))

#     word_counts = {}
#     for word in doc:
#         word_counts[word] = word_counts.get(word, 0) + 1
#     total_words = len(doc)
#     word_tf = {word: count / total_words for word, count in word_counts.items()}

#     unique_words = sorted(list(set(doc)))
#     for word in unique_words:
#         detail_rows.append({
#             "Dokumen": f"Doc {i+1}",
#             "Kata": word,
#             "TF": word_tf.get(word, 0),
#             "TF (Raw Count)": word_counts.get(word, 0),
#             "Total Kata Dokumen": total_words,
#             "IDF": word_idf.get(word, 0),
#             "TF-IDF": word_tfidf.get(word, 0)
#         })

# # Simpan ke Excel
# with pd.ExcelWriter("hasil_tf_idf.xlsx", engine="openpyxl") as writer:
#     pd.DataFrame(detail_rows).to_excel(writer, sheet_name="Detail TF-IDF", index=False)
#     df_tfidf.to_excel(writer, sheet_name="Matrix TF-IDF", index=False)

# print("Berhasil disimpan ke 'hasil_tf_idf.xlsx'")
# Out:
# Berhasil disimpan ke 'hasil_tf_idf.xlsx'

# %%
# # prompt: berdasarkan hasil tf-idf dalam file ini "/content/hasil_tf_idf.xlsx" terapkan Algoritma Jaccard Similarity untuk menghitung Similarity nya, taampilkaan hasilnya dan simpan dalam beentuk  exel

# # Membaca file hasil_tf_idf.xlsx
# try:
#     df_tfidf_matrix = pd.read_excel("/content/hasil_tf_idf.xlsx", sheet_name="Matrix TF-IDF")
# except FileNotFoundError:
#     print("Error: File 'hasil_tf_idf.xlsx' tidak ditemukan.")
#     exit() # Keluar dari eksekusi jika file tidak ditemukan

# # Mendapatkan matriks TF-IDF dari DataFrame
# tfidf_matrix_loaded = df_tfidf_matrix.values

# # Fungsi untuk menghitung Jaccard Similarity antara dua vektor TF-IDF
# def jaccard_similarity(vec1, vec2):
#     # Untuk Jaccard Similarity dengan vektor TF-IDF, kita bisa memperlakukannya sebagai
#     # himpunan fitur (kata) yang memiliki nilai TF-IDF > 0.
#     # Irisan (Intersection): Kata-kata yang muncul di kedua dokumen (memiliki nilai TF-IDF > 0 di kedua vektor).
#     # Gabungan (Union): Kata-kata yang muncul di salah satu atau kedua dokumen (memiliki nilai TF-IDF > 0 di salah satu atau kedua vektor).

#     # Mengidentifikasi indeks kata dengan nilai TF-IDF > 0
#     set1 = set(np.where(vec1 > 0)[0])
#     set2 = set(np.where(vec2 > 0)[0])

#     # Menghitung irisan dan gabungan
#     intersection = len(set1.intersection(set2))
#     union = len(set1.union(set2))

#     # Menghitung Jaccard Similarity
#     if union == 0:
#         return 0.0  # Jika tidak ada kata di kedua vektor, similarity 0
#     else:
#         return intersection / union

# # Hitung Jaccard Similarity untuk semua pasangan dokumen
# num_documents = tfidf_matrix_loaded.shape[0]
# jaccard_similarity_matrix = np.zeros((num_documents, num_documents))

# for i in range(num_documents):
#     for j in range(num_documents):
#         jaccard_similarity_matrix[i, j] = jaccard_similarity(tfidf_matrix_loaded[i], tfidf_matrix_loaded[j])

# # Tampilkan hasil Jaccard Similarity Matrix
# df_jaccard_similarity = pd.DataFrame(jaccard_similarity_matrix,
#                                      index=[f"Doc {i+1}" for i in range(num_documents)],
#                                      columns=[f"Doc {j+1}" for j in range(num_documents)])

# print("\n--- Jaccard Similarity Matrix ---")
# print(df_jaccard_similarity)

# # Simpan hasil Jaccard Similarity Matrix ke file Excel baru atau sheet baru di file yang sama
# output_excel_path = "/content/hasil_similarity_jaccard.xlsx"

# # Menggunakan mode 'w' untuk membuat file baru atau menimpa file yang ada
# # Jika ingin menambah sheet ke file hasil_tf_idf.xlsx, ubah mode menjadi 'a'
# # dan pastikan untuk menutup ExcelWriter dengan benar
# try:
#     with pd.ExcelWriter(output_excel_path, engine="openpyxl") as writer:
#         df_jaccard_similarity.to_excel(writer, sheet_name="Jaccard Similarity", index=True)
#     print(f"\nHasil Jaccard Similarity Matrix disimpan ke '{output_excel_path}'")
#     from google.colab import files
#     files.download("hasil_similarity_jaccard.xlsx")

# except Exception as e:
#     print(f"\nError saat menyimpan file Excel: {e}")
# Out:
# --- Jaccard Similarity Matrix ---
#           Doc 1     Doc 2     Doc 3   Doc 4     Doc 5
# Doc 1  1.000000  0.058824  0.000000  0.0000  0.058824
# Doc 2  0.058824  1.000000  0.045455  0.0000  0.000000
# Doc 3  0.000000  0.045455  1.000000  0.0000  0.045455
# Doc 4  0.000000  0.000000  0.000000  1.0000  0.062500
# Doc 5  0.058824  0.000000  0.045455  0.0625  1.000000
#
# Hasil Jaccard Similarity Matrix disimpan ke '/content/hasil_similarity_jaccard.xlsx'

# %%
def preprocessing(text):
    # Lowercase
    text = text.lower()

    # Hilangkan angka & tanda baca
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # Tokenisasi
    tokens = word_tokenize(text)

    # Hilangkan stopwords
    tokens = [word for word in tokens if word not in stop_words]

    # Stemming (opsional tapi disarankan)
    tokens = [stemmer.stem(word) for word in tokens]

    return " ".join(tokens)

# %%
# ini buat menggunakan ffungsi prosesing tteexx
df['text_combined'] = df['text_combined'].fillna('').apply(preprocessing)

# %%
print(preprocessing("Men Single-Breasted Bandhgala Suit Gold EthnoVogue"))
print(preprocessing("Women Bralette Bra Blue Laceandme"))
# Out:
# men singlebreast bandhgala suit gold ethnovogu
# women bralett bra blue laceandm

# %%
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df['text_combined'])

# %%
cosine_sim = cosine_similarity(tfidf_matrix)

# %%
def rekomendasi_final(gender, nama_produk, color, brand, data=df, tfidf=tfidf, tfidf_matrix=tfidf_matrix, top_n=6):
    input_text = f"{gender} {nama_produk} {color} {brand}"
    input_text = preprocessing(input_text)
    input_vec = tfidf.transform([input_text])
    cosine_sim = cosine_similarity(input_vec, tfidf_matrix).flatten()

    rekom_index = cosine_sim.argsort()[::-1][:top_n]
    scores = cosine_sim[rekom_index]

    result = data.iloc[rekom_index][['SimplifiedProductName', 'ProductBrand', 'PrimaryColor', 'Price (INR)', 'Description']].copy()
    result['Score'] = scores  # tambahkan kolom skor
    result['Score'] = result['Score'].round(4)

    return result

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Evaluasi rekomendasi
def evaluasi_rekomendasi(result):
    if 'Score' not in result.columns:
        raise ValueError("Kolom 'Score' tidak ditemukan pada hasil rekomendasi.")

    # Simulasi actual rating (misalnya dari skala 0.0 - 1.0, atau pakai data user nyata jika ada)
    np.random.seed(42)  # agar konsisten
    result['ActualRating'] = np.random.uniform(0, 1, size=len(result))  # simulasi

    # Evaluasi
    mae = mean_absolute_error(result['ActualRating'], result['Score'])
    mse = mean_squared_error(result['ActualRating'], result['Score'])

    print("📌 Evaluasi Rekomendasi:")
    print(f"MAE (Mean Absolute Error): {mae:.4f}")
    print(f"MSE (Mean Squared Error): {mse:.4f}")

    return mae, mse

# %%
df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2       10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...          ...                                                ...
# 12485   10261595  Laceandme Black Lace Non-Wired Lightly Padded ...
# 12486   10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12488   10261607  612 league Girls Navy Blue & White Printed Reg...
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  \
# 0             DKNY  Unisex        11745
# 1       EthnoVogue   Women         5810
# ...

# %%
hasil1 = rekomendasi_final('Men','Single-Breasted Bandhgala Suit','Gold','EthnoVogue')

# %%
hasil1
# Out:
#                 SimplifiedProductName ProductBrand PrimaryColor  Price (INR)  \
# 3      Single-Breasted Bandhgala Suit      Raymond         Blue         5599
# 10848  Single-Breasted Bandhgala Suit        V Dot        Beige         6499
# 604         Single-Breasted Bandhgala      Raymond       Maroon         3599
# 1339             Single-Breasted Suit         Parx         Blue         3599
# 1415             Single-Breasted Suit         Parx         Blue         3599
# 1916             Single-Breasted Suit         Parx         Blue         3599
#
#                                              Description   Score
# 3      Blue self-design bandhgala suitBlue self-desig...  0.7104
# 10848  Beige self-design Bandhgala Ethnic suitBeige e...  0.6417
# 604    Maroon self-design single breasted bandhgala b...  0.5474
# 1339   Blue solid party suitBlue solid regular-fit bl...  0.5048
# 1415   Blue solid party suitBlue solid regular-fit tu...  0.5048
# ...

# %%
# prompt: Menggunakan hasil1 DataFrame: MENGEVALUASI HASAIL REKOMENDASI MENGGUNAKAN  METODE MAe

import numpy as np
# Calculate the absolute difference between the 'Score' and 'ActualRating' columns
absolute_errors = np.abs(hasil1['Score'] - hasil1['ActualRating'])
# Calculate the Mean Absolute Error (MAE)
mae = np.mean(absolute_errors)
# Print the MAE
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# Mean Absolute Error (MAE): 0.27015224213205935

# %%
mae, mse = evaluasi_rekomendasi(hasil1)
# Out:
# 📌 Evaluasi Rekomendasi:
# MAE (Mean Absolute Error): 0.2702
# MSE (Mean Squared Error): 0.0824
